# %%
# Load and inspect data
import pandas as pd

url = 'https://www.sharkattackfile.net/spreadsheets/GSAF5.xls'
shark_attack = pd.read_excel(url)
shark_attack
# Out:
#              Date    Year        Type    Country              State  \
# 0     15 Mar 2024  2024.0  Unprovoked  AUSTRALIA         Queensland
# 1     04 Mar 2024  2024.0  Unprovoked        USA             Hawaii
# 2     02 Mar-2024  2024.0  Unprovoked        USA             Hawaii
# 3     25 Feb-2024  2024.0  Unprovoked  AUSTRALIA  Western Australia
# 4     14 Feb-2024  2024.0  Unprovoked      INDIA        Maharashtra
# ...           ...     ...         ...        ...                ...
# 6964          NaN     NaN         NaN        NaN                NaN
# 6965          NaN     NaN         NaN        NaN                NaN
# 6966          NaN     NaN         NaN        NaN                NaN
# 6967          NaN     NaN         NaN        NaN                NaN
# 6968          NaN     NaN         NaN        NaN                NaN
#
#                               Location  Activity                 Name  Sex  \
# ...

# %%
## five data cleaning techniques
# 1.Identify missing values, outliers, and inconsistencies.
# 2.Clean missing data, remove duplicates, standardize text.
# 3.Handle outliers and convert data types.
# 4.Create new features, normalize data, and encode categorical variables.
# 5.Save the cleaned and transformed dataset.

# %%
#Identify Missing Values
shark_attack.isnull().sum()
# Out:
# Date                25
# Year                27
# Type                43
# Country             75
# State              507
# Location           590
# Activity           611
# Name               245
# Sex                604
# Age               3019
# Injury              60
# Unnamed: 11        587
# Time              3551
# Species           3157
# Source              44
# pdf                170
# href formula       150
# href               173
# Case Number        171
# Case Number.1      172
# original order     170
# Unnamed: 21       6968
# Unnamed: 22       6967
# dtype: int64

# %%
#drop rows
shark_attack.dropna(inplace=True)

# %%
#fill missing values
shark_attack['Species'].fillna(shark_attack['Species'].mode()[0], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Species'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[152], line 2
#       1 #fill missing values
# ...

# %%
shark_attack['Time'].fillna(shark_attack['Time'].mode()[0], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[154], line 1
# ----> 1 shark_attack['Time'].fillna(shark_attack['Time'].mode()[0], inplace=True)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
# ...

# %%
# 2.Identify missing values, outliers, and inconsistencies.
#Check for Duplicates
shark_attack.duplicated()
# Out:
# Series([], dtype: bool)

# %%
#Identify Outliers
shark_attack.describe()
# Out:
#        Year  original order
# count   0.0             0.0
# mean    NaN             NaN
# std     NaN             NaN
# min     NaN             NaN
# 25%     NaN             NaN
# 50%     NaN             NaN
# 75%     NaN             NaN
# max     NaN             NaN

# %%
#Inconsistent Data Entry
shark_attack['Time'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
shark_attack.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Unnamed: 11', 'Time', 'Species ',
#        'Source', 'pdf', 'href formula', 'href', 'Case Number', 'Case Number.1',
#        'original order', 'Unnamed: 21', 'Unnamed: 22'],
#       dtype='object')

# %%
shark_attack[['Injury','Unnamed: 11','Time', 'Species ',
       'Source', 'pdf', 'href formula', 'href', 'Case Number', 'Case Number.1',
       'original order', 'Unnamed: 21', 'Unnamed: 22']]
# Out:
#                                         Injury Unnamed: 11   Time  \
# 0     Minor injuries to back, abdomen and legs         NaN  16h00
# 1               No injury, shark bit surfboard           N    NaN
# 2                     Lacerations to left foot           N  13h30
# 3                                   Leg bitten           N  11h30
# 4               Calf of lower left leg injured           N    NaN
# ...                                        ...         ...    ...
# 6964                                       NaN         NaN    NaN
# 6965                                       NaN         NaN    NaN
# 6966                                       NaN         NaN    NaN
# 6967                                       NaN         NaN    NaN
# 6968                                       NaN         NaN    NaN
#
#             Species                      Source  pdf  \
# 0        Tiger shark      Yahoo News, 3/15/2024  NaN
# 1     Tiger shark 8'          Surfer, 3/6/2024F  NaN
# ...

# %%
#Time/Number: Shark Attacks increase at Dawn and Dusk ?
shark_attack[['Type','Time']]
# Out:
# Empty DataFrame
# Columns: [Type, Time]
# Index: []

# %%
shark_attack.dtypes
# Out:
# Date               object
# Year              float64
# Type               object
# Country            object
# State              object
# Location           object
# Activity           object
# Name               object
# Sex                object
# Age                object
# Injury             object
# Unnamed: 11        object
# Time               object
# Species            object
# Source             object
# pdf                object
# href formula       object
# href               object
# Case Number        object
# Case Number.1      object
# original order    float64
# Unnamed: 21        object
# Unnamed: 22        object
# dtype: object

# %%
shark_attack.select_dtypes(include=['float64', 'object']).nunique()
# Out:
# Date              6003
# Year               259
# Type                12
# Country            225
# State              902
# Location          4514
# Activity          1587
# Name              5683
# Sex                  8
# Age                243
# Injury            4079
# Unnamed: 11         12
# Time               410
# Species           1675
# Source            5302
# pdf               6789
# href formula      6785
# href              6776
# Case Number       6777
# Case Number.1     6775
# original order    6797
# Unnamed: 21          1
# Unnamed: 22          2
# dtype: int64
